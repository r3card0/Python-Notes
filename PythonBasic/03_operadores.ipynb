# %% [markdown]
# # Operadores
#
# ## Objetivo: Aprender qué son los operadores, cuantos tipos hay y en que casos se usan.
#
#
# Python maneja varios tipos de operadores. Los operadores son los que manipulan el valor de los operandos. En la expresión **3 + 7 = 10**, los números 3 y 7 son llamados operandos y el símbolo **+** es llamado operador.
#
# En este tema se hablaran de los siguientes tipos de Operadores:
# 1. Aritméticos
# 2. Asignación
# 3. Comparación
# 4. Lógicos

# %% [markdown]
# ## Operadores Aritméticos

# %% [markdown]
# ![03_image01](/Users/ideasleon/platzi_edu/Entorno_f_DataScience/PythonNotes/Images/03_image01.png)

# %% [markdown]
# ![03_image01.png](attachment:03_image01.png)

# %% [markdown]
# Usa Python como calculadora!!

# %%
45 * 5
# Out:
# 225

# %% [markdown]
# Imprime los resultados usando el comando **print()**

# %%
print(20 + 10)  # suma
print(10 - 20)  # resta
print(20 * 10)  # multiplicación
print(20 / 10)  # división
print(20 % 10)  # módulo
print(2 ** 3)   # potencia
print(-11//3)   # redondeo de division
# Out:
# 30
# -10
# 200
# 2.0
# 0
# 8
# -4

# %% [markdown]
# ## Operadores de Asignación
#
# En Python, se utiliza un operador de asignación para **asignar** valores a una variable.
#
# El más usado y conocido es el operador de asignación **"="**. En matemáticas se usa y se lee como igual a. Pero en Python es para asignar un valor a una variable. Por ejemplo, la variable "**x**" se le asigna el valor de "**20**".

# %%
x = 20
print(x)
# Out:
# 20

# %% [markdown]
# Ejercicio # 1. Asigna el valor del texto: 'La vida es bella', a la variable **vida**. Imprime el valor de **vida**. Copia o escribe el texto desde las comillas simples.

# %%
# Ejercicio # 1. 
# asignar valor a la variable
# imprimir el valor de la variable

# %% [markdown]
# Imágen que muestra más Operadores de Asignación.

# %% [markdown]
# ![03_image02](/Users/ideasleon/platzi_edu/Entorno_f_DataScience/PythonNotes/Images/03_image02.png)

# %% [markdown]
# ![03_image02.png](attachment:03_image02.png)

# %% [markdown]
# ## Operadores de Comparación
#
# Los Operadores de Comparación son usado para comparar dos valores. En Python hay 6 operadores de comparación. Retornan el valor True si los valores satisfacen la condición del primer operando.

# %% [markdown]
# ![03_image03](/Users/ideasleon/platzi_edu/Entorno_f_DataScience/PythonNotes/Images/03_image03.png)

# %% [markdown]
# ![03_image03.png](attachment:03_image03.png)

# %% [markdown]
# Ejercicio # 2. Observa las siguientes comparaciones. La comparación dá como resultado "**True**". Hay expresiones "**comentadas**". Una expresión comentada es aquella que tiene el símbolo "**#**". Estas expresiones Python no las toma encuenta y no las ejecuta. Borra el símbolo **#** de la expresión y ejecutala para obervar el resultado.

# %%
print(1000 == 1000)     # igual
#print(0 == 3)       
print(2 != 3)           # NO igual
#print(5 != 5)       
print( 4 < 6)           # 4 es menor que 6
#print( 4 > 6)       
print( 30 > 6)          # 30 es mayor que 6
#print( 30 < 6)       
print( 50 >= 10)        # 50 es mayor o igual que 6
#print( 50 <= 10)  
print(13 <= 45)         # 13 es menor o igual a 45   
#print(13 >= 45)
# Out:
# True
# True
# True
# True
# True
# True

# %% [markdown]
# ## Operadores Lógicos

# %% [markdown]
# Los operadores lógicos son usados para combinar condicionales.
#
# Los operadores son: **and**, **or** y **not**

# %% [markdown]
# ![03_image04](/Users/ideasleon/platzi_edu/Entorno_f_DataScience/PythonNotes/Images/03_image04.png)

# %% [markdown]
# ![03_image04.png](attachment:03_image04.png)

# %%
x = 5
print(x > 3 and x < 10)
print(x > 3 or x < 2 )
print(not(x > 3 and x < 10))
# Out:
# True
# True
# False

# %% [markdown]
# ## Resumen
#
# 1. Python puede ser usado como calculadora ya que realiza operaciones artiméticas comunes.
# 2. Se conocieron los operadores:aritméticos, de asignación, de comparación y lógicos.
# 3. El operador de asignacion es **=** y es usado para **asignar** valores a las variables, mientras que el operador de comparación  **==**, se refiere como igual a.
# 4. Los operadores de comparación evalúan dos valores y retornan los valores **True** o **False** según sea el caso.

# %% [markdown]
# ## Referencias
#
# [Curso Básico de Python](https://platzi.com/clases/python/)
#
# [Python.org](https://docs.python.org/3/tutorial/introduction.html#using-python-as-a-calculator)
#
# [Basic Operators](https://www.tutorialspoint.com/python/python_basic_operators.htm)
